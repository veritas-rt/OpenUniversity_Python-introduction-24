# %% [markdown]
# <a href="https://colab.research.google.com/github/veritas-rt/OpenUniversity_Python-introduction-24-/blob/main/11_%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E3%81%A8%E3%81%AF%E4%BD%95%E3%81%8B_%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E5%85%A5%E9%96%80Python24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 第1章 プログラミング事始め・文字列・データ型

# %% [markdown]
#  * 左上の「ファイル」を開いて、「ドライブにコピーを保存」をしてください。
#  * 自分のGoogleドライブに、そのファイルが保存されます。ファイル名は「のコピー」が、最後（右端）についています。それを利用して学習・演習を進めて下さい。

# %% [markdown]
# プログラミングとはどういうことか、プログラミング環境 Google Colaboratory の使い方を説明します。そして、文字列を利用したプログラムと、Python の「データ型」について学びます。

# %% [markdown]
# # 1.1 プログラミングとは何か

# %% [markdown]
# ### 手順とは
#
# * 以下のことを含む作業
#  * 順番（順序）
#  * 条件判断（制御）
#  * 繰り返し（反復）（「待つ」も含まれる）
#
# * プログラム
#  * コンピュータ用に記述された手順
#  * プログラミング言語とはプログラムの書き方
#  * プログラムを作ることをプログラミングという

# %% [markdown]
# 私達は、日常生活で、いろいろな作業を行います。その作業には「順番」があります。また、一定の条件を満たしたときにだけ行う作業もあります。さらに、「待つ」「繰り返す」ということも、作業のひとつと言えます。
#
# このように、順番があり、条件に影響され、また、繰り返したり、待ったりすることによって進められることは、「手順」と呼ばれます。
#
# コンピュータが動作する際も、この「順番」「条件」「繰り返し」「待つ」といったことを行っています。こういった行為を組み合わせることで動作する機械が、コンピュータなのです。
#
# ところで、手順をコンピュータに伝えるときに使われる「文章」を、プログラムといいます。そして、その文章の書き方のことを、プログラミング言語といいます。
#
# いわば、プログラムとは、手順を、コンピュータにわかりやすい文法で書いた文章そのものなのです。
#
# そして、そのプログラムを作る作業を、プログラミングといいます。

# %% [markdown]
# ### プログラミングを学ぼう
#
# * プログラムはコンピュータの動作を決める
#  * プログラミングを学ぶと、コンピュータを意のままにあやつれる
#  * プログラミングができることは、コンピュータを理解する助けになる
# * でも、現在のコンピュータは複雑な仕組みで動作
#  * すべてを習得することは容易ではない
# * この授業では、プログラミング言語 Python を利用する
#  * 統計、科学技術計算、人工知能でも実用的に使われている
#  * 2015年以降、利用者急増中（教材が多い）

# %% [markdown]
# プログラミングができると、コンピュータを意のままに動作させることができます。しかし、実は、現在のコンピュータは、その内部が非常に複雑で、その一つ一つの部品を制御するプログラムは、非常に複雑に作られています。したがって、「ちょっとプログラミングを勉強した」程度では、コンピュータの動作を根本から理解することは不可能です。しかし、プログラミングの学習はコンピュータの仕組みを、すこし掘り下げて理解するのに役に立つのです。
#
# この授業で取り上げるのは、 Python というプログラミング言語です。この言語の文法に従って記述されたプログラムを利用すると、様々な計算（特に、統計、科学技術計算や、人工知能に関する計算）をすることができるようになります。そしてそれは、コンピュータが、どのように動作するのかを理解するために、とても役に立つでしょう。
#
# つまり、プログラミングができることは、コンピュータの動作を正しく考えられるようになることにつながっていくのです。

# %% [markdown]
# ### プログラムを実行する仕組み
#
# * 言語処理系（言語処理システム）
#  * 人間が書いたプログラムを実行する仕組み
#  * 言語処理系もまた、プログラムである
#  * 処理系を作るのは非常に高度なコンピュータ科学の習得が必要
#
# * 言語処理系の動作
#  1. 人間が書いたプログラム
#  2. OSに命令を渡す
#  3. OSがCPUに命令を渡す
#  4. コンピュータが動作する

# %% [markdown]
# コンピュータのプログラムは、コンピュータによってどのように実行されているのでしょうか？それは、実は簡単なことではありません。ですが、ひとつ重要なことを指摘しておきます。
#
# それは、「プログラムを理解して、コンピュータを動作させる仕組みもまた、プログラムによって書かれている」ということです。この、「人間が書いたプログラムを理解して、コンピュータを動作させる仕組み」のことを、「言語処理系」といいます。言語処理系を作成するには、さまざまなコンピュータ科学や工学の知識を必要とします。
#
# 少しだけ丁寧に記述すると、次のようになっています。
#
# 1. 人間が書いたプログラムを、言語処理系が読み出して、CPUへの命令を送る。
# 2. CPUへの命令は、OS（オペレーティング・システム）が受け取って、適切なタイミングでCPUに伝える。
# 3. CPUがプログラムに沿った動作を行い、結果として、計算が行われたり、記憶が行われたり、あるいは、画面に文字や画像を出したり、音を鳴らしたり、ネットワークにデータを流したり（受け取ったり）する。

# %% [markdown]
# ## 初めての Google Colaboratory

# %% [markdown]
# ### Google Colaboratory とは
#
# * Python 言語の言語処理系のひとつ
# * Google 社によって提供されている
#  * 他のプログラミング言語用に改造もできる
#
# * 「ノートブック」と呼ばれるファイルを利用する
#  * 同じノートブックを多数の人で共有可能
#  * 自分のドライブにコピーを作れば、自分でも編集可能

# %% [markdown]
# Google Colaboratory は、Google 社によって提供された、webブラウザでプログラミングを学んだり、実際にプログラムを利用して情報処理を行う仕組みです。
#
# 教材と、プログラミングの環境が一体化されているので、教材を進めながらプログラムを作って試すことができます。この教材も、Google Colaboratory を使って書かれています。
#
# 主に、Python 言語を学ぶためのものですが、C言語や、R言語を学ぶように改造されたものも存在します。
#
# ここでは、この授業の教材をつかった学び方を、まず、説明します。

# %% [markdown]
# 1. 次のURLを開いてください。<br>
# https://colab.research.google.com/drive/1Oi7-bvuy31sHD909ZRY4lXyMoYIGd0Fw?usp=sharing
#   * 左上の「ファイル」を開いて、「ドライブにコピーを保存」をしてください。
#   * 自分のGoogleドライブに、そのファイルが保存されます。ファイル名は「のコピー」が、最後（右端）についています。それを利用して学習・演習を進めて下さい。

# %% [markdown]
# ![スクリーンショット 2022-12-26 16.31.52.png](data:image/png;base64,...)

# %% [markdown]
# 2.   実行する前に、次の準備をして下さい。
#
#   1. 右上の歯車アイコンを開く
#   2. 出てきたメニューの左「サイト」タブを開く
#      + （好みに応じて）「モード」を light（背景が白で、文字が黒） あるいは　dark（背景が黒で文字が白） にする。
#   3. 出てきたメニューの左「エディタ」タブを開く
#      + フォントサイズを各自の好みの大きさにする。
#      + 「インデント幅（スペース）」は 4 にする。
#      + 次のチェックボックスは、2,3,4,5番目をチェックし、他を外す。
#          + 「コード入力時の候補を自動的に表示する」のチェックを外す。
#          + 「行番号を表示」と「インデントガイドの表示」「エディタでコードの折りたたみを可能にする」「コードセルで閉じかっこと閉じ引用符を自動的に追加する」をチェックする。
#          +「Enter キーで候補を確定」「フォントの合字」のチェックを外す。
#      + 「コードの診断」は、「Syntax checking」にする。
#  4. その後、右下の「保存」を選んでメニューを閉じる。

# %% [markdown]
# ![スクリーンショット 2022-12-01 10.04.56.png](data:image/png;base64,...)

# %% [markdown]
# # （次の教材）1.2 文字列
# * https://colab.research.google.com/drive/1Hd2JokC6hs_X4bOI84QslRPKZSxomL6f
